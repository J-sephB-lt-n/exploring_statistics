# %%
# code stolen from:
# https://github.com/keras-team/keras-io/blob/master/examples/structured_data/structured_data_classification_from_scratch.py

# %%
"""
## Setup
"""

import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %%
"""
## Preparing the data
Let's download the data and load it into a Pandas dataframe:
"""

file_url = "http://storage.googleapis.com/download.tensorflow.org/data/heart.csv"
dataframe = pd.read_csv(file_url)

# %%
"""
The dataset includes 303 samples with 14 columns per sample (13 features, plus the target
label):
"""

dataframe.shape
# Out:
# (303, 14)

# %%
"""
Here's a preview of a few samples:
"""

dataframe.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# # wide & deep exploration

# %% [markdown]
# question                                               | completed
# -------------------------------------------------------|------------
# categorical vbls with unseen values in test set?       | no
# wide & deep model?                                     | yes
# embedded categorical variables                         | no
# crossed categorical variables in dataset first         | no
# normalize numeric variables in dataset first           | yes

# %%
experiment_data = dataframe[['target','slope','age','sex','thal','restecg']].copy()

experiment_data['sex'] = np.select( condlist = [ experiment_data['sex'] == 0,
                                                 experiment_data['sex'] == 1
                                               ],
                                    choicelist = [ 'female', 'male' ],
                                    default = None
                                  )

experiment_data['restecg'] = 'ecg' + experiment_data['restecg'].astype(str) 

experiment_data.sample(10)
# Out:
#      target  slope  age     sex        thal restecg
# 46        0      1   65  female      normal    ecg2
# 286       0      1   45    male      normal    ecg2
# 195       1      1   52    male  reversible    ecg0
# 183       1      3   56    male  reversible    ecg2
# 38        1      2   55    male  reversible    ecg0
# 88        0      2   51    male      normal    ecg2
# 15        0      1   57    male      normal    ecg0
# 16        0      3   48    male  reversible    ecg0
# 163       0      1   46  female      normal    ecg0
# 12        1      2   56    male       fixed    ecg2

# %%
# prepare features for model:

# normalize numeric variables:
experiment_data['slope'] = ( experiment_data['slope'] - np.mean(experiment_data['slope']) ) / np.std(experiment_data['slope'])  # normalize "slope" 
experiment_data['age'] = ( experiment_data['age'] - np.mean(experiment_data['age']) ) / np.std(experiment_data['age'])  # normalize "age" 

# create crossed features:
features_to_cross = ['sex','thal','restecg']
import itertools
for combination in itertools.combinations(features_to_cross,2):
    experiment_data[ combination[0]+'_x_'+combination[1] ] = experiment_data[ combination[0] ] + '_' + experiment_data[ combination[1] ]

experiment_data.sample(10)
# Out:
#      target     slope       age     sex        thal restecg       sex_x_thal  \
# 46        0 -0.957863  1.156026  female      normal    ecg2    female_normal
# 26        0 -0.957863  0.378376  female      normal    ecg0    female_normal
# 14        0 -0.957863 -0.288181    male  reversible    ecg0  male_reversible
# 256       0 -0.957863  0.711654  female      normal    ecg2    female_normal
# 0         0  2.284959  0.933840    male       fixed    ecg2       male_fixed
# 289       0 -0.957863  1.822583  female      normal    ecg2    female_normal
# 120       0  0.663548  0.489468  female      normal    ecg0    female_normal
# 45        0 -0.957863 -1.176924    male      normal    ecg2      male_normal
# 107       1  0.663548  0.600561    male  reversible    ecg2  male_reversible
# 62        0  0.663548  0.822747    male  reversible    ecg0  male_reversible
#
#     sex_x_restecg   thal_x_restecg
# 46    female_ecg2      normal_ecg2
# 26    female_ecg0      normal_ecg0
# 14      male_ecg0  reversible_ecg0
# 256   female_ecg2      normal_ecg2
# 0       male_ecg2       fixed_ecg2
# 289   female_ecg2      normal_ecg2
# 120   female_ecg0      normal_ecg0
# 45      male_ecg2      normal_ecg2
# 107     male_ecg2  reversible_ecg2
# 62      male_ecg0  reversible_ecg0

# %%
from tensorflow.keras.layers.experimental.preprocessing import CategoryEncoding
from tensorflow.keras.layers.experimental.preprocessing import StringLookup

def encode_string_categorical_feature(feature, name, dataset):
     # this function from https://github.com/keras-team/keras-io/blob/master/examples/structured_data/structured_data_classification_from_scratch.py
    
    # Create a StringLookup layer which will turn strings into integer indices
    index = StringLookup()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    index.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = index(feature)

    # Create a CategoryEncoding for our integer indices
    encoder = CategoryEncoding(output_mode="binary")

    # Prepare a dataset of indices
    feature_ds = feature_ds.map(index)

    # Learn the space of possible indices
    encoder.adapt(feature_ds)

    # Apply one-hot encoding to our indices
    encoded_feature = encoder(encoded_feature)
    
    return encoded_feature

# %%
# one hot encode the categorical variables:
#experiment_data = pd.get_dummies( 
#                experiment_data,
#                columns = ['sex','thal','restecg','sex_x_thal','sex_x_restecg','thal_x_restecg']
#              )
#experiment_data.sample(10)

# %%
# train/validation 80%/20% split: 
val_data = experiment_data.sample(frac=0.2, random_state=1337)
train_data = experiment_data.drop(val_data.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_data), len(val_data))
)
# Out:
# Using 242 samples for training and 61 for validation

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")    # pull out y (response) column 
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

train_ds = dataframe_to_dataset(train_data)
val_ds = dataframe_to_dataset(val_data)

# batch the datasets:
train_ds = train_ds.batch(32)
val_ds = val_ds.batch(32)

# %%
# Numerical features
slope = keras.Input(shape=(1,), name='slope')
age = keras.Input(shape=(1,), name='age')

# Categorical features:
sex = keras.Input(shape=(1,), name='sex', dtype='string')
sex_encoded = encode_string_categorical_feature( feature = sex, 
                                                    name = 'sex', 
                                                 dataset = train_ds
                                               )
thal = keras.Input(shape=(1,), name='thal', dtype='string')
thal_encoded = encode_string_categorical_feature( feature = thal, 
                                                     name = 'thal', 
                                                  dataset = train_ds
                                               )
restecg = keras.Input(shape=(1,), name='restecg', dtype='string')
restecg_encoded = encode_string_categorical_feature( feature = restecg, 
                                                        name = 'restecg', 
                                                     dataset = train_ds
                                               )

sex_x_thal = keras.Input(shape=(1,), name='sex_x_thal', dtype='string')
sex_x_thal_encoded = encode_string_categorical_feature( feature = sex_x_thal,
                                                        name = 'sex_x_thal',   
                                                        dataset = train_ds
                                                      )

sex_x_restecg = keras.Input(shape=(1,), name='sex_x_restecg', dtype='string')
sex_x_restecg_encoded = encode_string_categorical_feature( feature = sex_x_restecg,
                                                           name = 'sex_x_restecg',       
                                                           dataset = train_ds 
                                                         )

thal_x_restecg = keras.Input(shape=(1,), name='thal_x_restecg', dtype='string')
thal_x_restecg_encoded = encode_string_categorical_feature( feature = thal_x_restecg, 
                                                            name = 'thal_x_restecg',
                                                            dataset = train_ds
                                                          )

all_inputs = [
   slope,
   age,
   sex,
   thal,
   restecg, 
   sex_x_thal,
   sex_x_restecg,
   thal_x_restecg, 
]

# %%
all_features = layers.concatenate(
    [
        slope,
        age,
        sex_encoded,
        thal_encoded,
        restecg_encoded,
        sex_x_thal_encoded,
        sex_x_restecg_encoded,
        thal_x_restecg_encoded 
    ]
)

features_for_wide = layers.concatenate( 
    [ 
        sex_encoded,
        thal_encoded,
        restecg_encoded,
        sex_x_thal_encoded,
        sex_x_restecg_encoded,
        thal_x_restecg_encoded         
    ],
    name = 'inputs_for_wide'
)

features_for_deep = layers.concatenate( 
    [ 
        sex_encoded, 
        age,
        slope,
    ],
    name = 'inputs_for_deep'
)

# %%
wide_output = layers.Dense(1, 
                           activation='sigmoid',
                           name = 'wide_part',
                          )(features_for_wide)

deep_layer1 = layers.Dense( 32, 
                            activation='relu',
                            name = 'deep1' 
                          )(features_for_deep)
deep_output = layers.Dense( 1, 
                            activation='sigmoid',
                            name = 'deep2'
                          )(deep_layer1)

combine_model_outputs = layers.concatenate( 
    [ 
        wide_output,
        deep_output,
    ],
    name = 'combine_wide_and_deep'
)

final_output = layers.Dense( 1, 
                             activation='sigmoid',
                             name = 'final_model_output'
                           )(combine_model_outputs)

model = keras.Model(all_inputs, final_output)
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])

keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
#x = layers.Dense(32, activation="relu")(all_features)
#x = layers.Dropout(0.5)(x)
#output = layers.Dense(1, activation="sigmoid")(x)
#model = keras.Model(all_inputs, output)
#model.compile("adam", "binary_crossentropy", metrics=["accuracy"])
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
model.summary()

# %%
model.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6171 - accuracy: 0.7149 - val_loss: 0.5761 - val_accuracy: 0.7705
# Epoch 2/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6142 - accuracy: 0.7149 - val_loss: 0.5733 - val_accuracy: 0.7705
# Epoch 3/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6117 - accuracy: 0.7149 - val_loss: 0.5704 - val_accuracy: 0.7705
# Epoch 4/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6089 - accuracy: 0.7149 - val_loss: 0.5677 - val_accuracy: 0.7705
# Epoch 5/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6064 - accuracy: 0.7149 - val_loss: 0.5649 - val_accuracy: 0.7705
# Epoch 6/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6038 - accuracy: 0.7149 - val_loss: 0.5621 - val_accuracy: 0.7705
# Epoch 7/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6014 - accuracy: 0.7149 - val_loss: 0.5592 - val_accuracy: 0.7705
# Epoch 8/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5986 - accuracy: 0.7149 - val_loss: 0.5567 - val_accuracy: 0.7705
# Epoch 9/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5962 - accuracy: 0.7149 - val_loss: 0.5542 - val_accuracy: 0.7705
# Epoch 10/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5940 - accuracy: 0.7149 - val_loss: 0.5514 - val_accuracy: 0.7705
# Epoch 11/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5916 - accuracy: 0.7149 - val_loss: 0.5490 - val_accuracy: 0.7705
# Epoch 12/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5891 - accuracy: 0.7149 - val_loss: 0.5468 - val_accuracy: 0.7705
# Epoch 13/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5869 - accuracy: 0.7149 - val_loss: 0.5446 - val_accuracy: 0.7705
# Epoch 14/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5846 - accuracy: 0.7149 - val_loss: 0.5425 - val_accuracy: 0.7705
# Epoch 15/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5824 - accuracy: 0.7149 - val_loss: 0.5403 - val_accuracy: 0.7705
# Epoch 16/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5802 - accuracy: 0.7149 - val_loss: 0.5380 - val_accuracy: 0.7705
# Epoch 17/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5779 - accuracy: 0.7149 - val_loss: 0.5359 - val_accuracy: 0.7705
# Epoch 18/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5757 - accuracy: 0.7149 - val_loss: 0.5339 - val_accuracy: 0.7705
# Epoch 19/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5735 - accuracy: 0.7149 - val_loss: 0.5320 - val_accuracy: 0.7705
# Epoch 20/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5713 - accuracy: 0.7149 - val_loss: 0.5301 - val_accuracy: 0.7705
# Epoch 21/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5691 - accuracy: 0.7149 - val_loss: 0.5283 - val_accuracy: 0.7705
# Epoch 22/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5670 - accuracy: 0.7149 - val_loss: 0.5264 - val_accuracy: 0.7705
# Epoch 23/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5649 - accuracy: 0.7149 - val_loss: 0.5248 - val_accuracy: 0.7705
# Epoch 24/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5626 - accuracy: 0.7149 - val_loss: 0.5230 - val_accuracy: 0.7705
# Epoch 25/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5606 - accuracy: 0.7149 - val_loss: 0.5211 - val_accuracy: 0.7705
# Epoch 26/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5584 - accuracy: 0.7149 - val_loss: 0.5194 - val_accuracy: 0.7705
# Epoch 27/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5563 - accuracy: 0.7149 - val_loss: 0.5179 - val_accuracy: 0.7705
# Epoch 28/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5544 - accuracy: 0.7149 - val_loss: 0.5162 - val_accuracy: 0.7705
# Epoch 29/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5523 - accuracy: 0.7149 - val_loss: 0.5145 - val_accuracy: 0.7705
# Epoch 30/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5502 - accuracy: 0.7149 - val_loss: 0.5131 - val_accuracy: 0.7705
# Epoch 31/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5482 - accuracy: 0.7149 - val_loss: 0.5118 - val_accuracy: 0.7705
# Epoch 32/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5462 - accuracy: 0.7149 - val_loss: 0.5105 - val_accuracy: 0.7705
# Epoch 33/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5443 - accuracy: 0.7149 - val_loss: 0.5091 - val_accuracy: 0.7705
# Epoch 34/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5423 - accuracy: 0.7149 - val_loss: 0.5077 - val_accuracy: 0.7705
# Epoch 35/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5404 - accuracy: 0.7149 - val_loss: 0.5064 - val_accuracy: 0.7705
# Epoch 36/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5385 - accuracy: 0.7149 - val_loss: 0.5052 - val_accuracy: 0.7705
# Epoch 37/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5366 - accuracy: 0.7149 - val_loss: 0.5041 - val_accuracy: 0.7705
# Epoch 38/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5348 - accuracy: 0.7149 - val_loss: 0.5030 - val_accuracy: 0.7705
# Epoch 39/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5330 - accuracy: 0.7149 - val_loss: 0.5017 - val_accuracy: 0.7705
# Epoch 40/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5313 - accuracy: 0.7149 - val_loss: 0.5007 - val_accuracy: 0.7705
# Epoch 41/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5295 - accuracy: 0.7149 - val_loss: 0.4997 - val_accuracy: 0.7705
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5278 - accuracy: 0.7149 - val_loss: 0.4987 - val_accuracy: 0.7705
# Epoch 43/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5261 - accuracy: 0.7149 - val_loss: 0.4977 - val_accuracy: 0.7705
# Epoch 44/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5245 - accuracy: 0.7149 - val_loss: 0.4969 - val_accuracy: 0.7705
# Epoch 45/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5229 - accuracy: 0.7149 - val_loss: 0.4961 - val_accuracy: 0.7705
# Epoch 46/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5213 - accuracy: 0.7149 - val_loss: 0.4952 - val_accuracy: 0.7705
# Epoch 47/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5196 - accuracy: 0.7149 - val_loss: 0.4943 - val_accuracy: 0.7705
# Epoch 48/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5182 - accuracy: 0.7149 - val_loss: 0.4934 - val_accuracy: 0.7705
# Epoch 49/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5167 - accuracy: 0.7149 - val_loss: 0.4925 - val_accuracy: 0.7705
# Epoch 50/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5152 - accuracy: 0.7149 - val_loss: 0.4919 - val_accuracy: 0.7705

# %%
# can extract the weights from model.layers:
model.layers
